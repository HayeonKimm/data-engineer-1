# %%
import sys
import pyspark
from pyspark import SparkConf, SparkContext
from pyspark.sql import SparkSession
from pyspark.sql.functions import explode
import pandas as pd
import numpy as np

# %%
spark = SparkSession.builder.appName('dataframe').getOrCreate()
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)

# %%
# 서버와 스파크 사용할 때
df_bus_100100073_weather = pd.read_csv("/home/lab01/df_bus_100100073_weather.csv")

# %%
df_bus_100100073_weather = df_bus_100100073_weather[df_bus_100100073_weather['stationNm_x'].isin(['순천향대학병원.한남오거리','신사역.푸른저축은행','논현역','지하철2호선강남역','신분당선강남역','래미안아파트.파이낸셜뉴스','뱅뱅사거리'])]
df_bus_100100073_weather = df_bus_100100073_weather[df_bus_100100073_weather['stationNm_y'].isin(['순천향대학병원.한남오거리','신사역.푸른저축은행','논현역','지하철2호선강남역','신분당선강남역','래미안아파트.파이낸셜뉴스','뱅뱅사거리'])]

# %%
df_bus_100100073_weather
# Out:
#        Unnamed: 0  baseDateMinute    plainNo  fullSectDist        gpsX  \
# 231           231    202108101125  서울70사6587         2.673  127.005729
# 235           235    202108101157  서울74사1821         2.673  127.006231
# 242           242    202108101104  서울74사2510         2.673  127.005729
# 243           243    202108101115  서울74사2562         2.673  127.006218
# 247           247    202108101101  서울74사4605         2.673  127.005729
# ...           ...             ...        ...           ...         ...
# 30543       30543    202108120858  서울74사7608         0.508  127.030439
# 30563       30563    202108140853  서울74사4110         0.888  127.020291
# 30566       30566    202108170852  서울74사7608         0.888  127.019957
# 30570       30570    202108110858  서울75사1365         0.888  127.019981
# 30690       30690    202108120855  서울75사1653         2.673  127.006218
#
#             gpsY  sectionId  stopFlag  congetion  busRouteId  seq  station_x  \
# 231    37.535491  121600088         1          4   100100073   31  102000071
# 235    37.535042  121600088         0          3   100100073   31  102000071
# 242    37.535491  121600088         1          4   100100073   31  102000071
# 243    37.535319  121600088         1          4   100100073   31  102000071
# 247    37.535491  121600088         1          4   100100073   31  102000071
# ...          ...        ...       ...        ...         ...  ...        ...
# 30543  37.491627  121607998         1          3   100100073   36  121000007
# 30563  37.513191  121600010         0          3   100100073   32  121000015
# 30566  37.514282  121600010         0          3   100100073   32  121000015
# 30570  37.514205  121600010         1          4   100100073   32  121000015
# 30690  37.535319  121600088         1          4   100100073   31  102000071
#
#          stationNm_x  nx_x  ny_x  station_y stationNm_y  nx_y  ny_y  \
# 231    순천향대학병원.한남오거리    60   126  121000015  신사역.푸른저축은행    61   126
# 235    순천향대학병원.한남오거리    60   126  121000015  신사역.푸른저축은행    61   126
# 242    순천향대학병원.한남오거리    60   126  121000015  신사역.푸른저축은행    61   126
# 243    순천향대학병원.한남오거리    60   126  121000015  신사역.푸른저축은행    61   126
# 247    순천향대학병원.한남오거리    60   126  121000015  신사역.푸른저축은행    61   126
# ...              ...   ...   ...        ...         ...   ...   ...
# 30543  래미안아파트.파이낸셜뉴스    61   125  121000005       뱅뱅사거리    61   125
# 30563     신사역.푸른저축은행    61   126  121000013         논현역    61   125
# 30566     신사역.푸른저축은행    61   126  121000013         논현역    61   125
# 30570     신사역.푸른저축은행    61   126  121000013         논현역    61   125
# 30690  순천향대학병원.한남오거리    60   126  121000015  신사역.푸른저축은행    61   126
#
#        nextBaseDateTime nextPlainNo  baseDateHour  interval  nx   ny  PTY  \
# 231        202108101132   서울70사6587    2021081011         7  60  126    0
# 235        202108101202   서울74사1821    2021081011         5  60  126    0
# 242        202108101113   서울74사2510    2021081011         9  60  126    0
# 243        202108101122   서울74사2562    2021081011         7  60  126    0
# 247        202108101107   서울74사4605    2021081011         6  60  126    0
# ...                 ...         ...           ...       ...  ..  ...  ...
# 30543      202108120901   서울74사7608    2021081208         3  61  125    0
# 30563      202108140855   서울74사4110    2021081408         2  61  126    0
# 30566      202108170856   서울74사7608    2021081708         4  61  126    0
# 30570      202108110902   서울75사1365    2021081108         4  61  126    0
# 30690      202108120904   서울75사1653    2021081208         9  60  126    0
#
#        REH  RN1   T1H  UUU  VEC  VVV  WSD
# 231     60  0.0  30.5  2.0  226  1.9  2.8
# 235     60  0.0  30.5  2.0  226  1.9  2.8
# 242     60  0.0  30.5  2.0  226  1.9  2.8
# 243     60  0.0  30.5  2.0  226  1.9  2.8
# 247     60  0.0  30.5  2.0  226  1.9  2.8
# ...    ...  ...   ...  ...  ...  ...  ...
# 30543   69  0.0  28.5 -0.7  141  1.0  1.3
# 30563   61  0.0  26.5 -2.8   76 -0.6  3.0
# 30566   56  0.0  26.6 -1.8   81 -0.2  1.9
# 30570   78  0.0  25.9 -0.1    5 -2.0  2.1
# 30690   68  0.0  27.5 -1.5   51 -1.2  2.1
#
# [4216 rows x 33 columns]

# %%
df_bus_100100073_weather['sectionId'] = df_bus_100100073_weather['sectionId'].astype('object')
df_bus_100100073_weather['PTY'] = df_bus_100100073_weather['PTY'].astype('object')

# %%
df_bus_100100073_weather['baseDateMinute']=df_bus_100100073_weather['baseDateMinute'].astype(str)
df_bus_100100073_weather['baseDateMinute']=df_bus_100100073_weather['baseDateMinute'].str[-4:]

# %%
df_bus_100100073_weather['baseHr']=df_bus_100100073_weather['baseDateMinute'].str[:2]
df_bus_100100073_weather['baseHr']=df_bus_100100073_weather['baseHr'].astype(int)
df_bus_100100073_weather['baseMn']=df_bus_100100073_weather['baseDateMinute'].str[2:]
df_bus_100100073_weather['baseMn']=df_bus_100100073_weather['baseMn'].astype(int)

# %%
#분으로만 시간 표기하기
#1125 -> 685
df_bus_100100073_weather['baseTm']= df_bus_100100073_weather['baseHr']*60 + df_bus_100100073_weather['baseMn']

# %%
df_bus_100100073_weather = df_bus_100100073_weather.drop({'baseHr','baseMn','Unnamed: 0'},axis=1)

# %%
df_bus_100100073_weather = df_bus_100100073_weather[df_bus_100100073_weather['PTY']!=-999]

# %%
df_bus_100100073_weather['newCon'] = [x-2 if x> 2 else 0 for x in df_bus_100100073_weather['congetion']]

# %%
df_bus_100100073_weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4156 entries, 231 to 30690
# Data columns (total 34 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   baseDateMinute    4156 non-null   object
#  1   plainNo           4156 non-null   object
#  2   fullSectDist      4156 non-null   float64
#  3   gpsX              4156 non-null   float64
#  4   gpsY              4156 non-null   float64
#  5   sectionId         4156 non-null   object
#  6   stopFlag          4156 non-null   int64
#  7   congetion         4156 non-null   int64
#  8   busRouteId        4156 non-null   int64
#  9   seq               4156 non-null   int64
#  10  station_x         4156 non-null   int64
#  11  stationNm_x       4156 non-null   object
#  12  nx_x              4156 non-null   int64
#  13  ny_x              4156 non-null   int64
#  14  station_y         4156 non-null   int64
#  15  stationNm_y       4156 non-null   object
#  16  nx_y              4156 non-null   int64
#  17  ny_y              4156 non-null   int64
#  18  nextBaseDateTime  4156 non-null   int64
#  19  nextPlainNo       4156 non-null   object
#  20  baseDateHour      4156 non-null   int64
#  21  interval          4156 non-null   int64
#  22  nx                4156 non-null   int64
#  23  ny                4156 non-null   int64
#  24  PTY               4156 non-null   object
#  25  REH               4156 non-null   int64
#  26  RN1               4156 non-null   float64
#  27  T1H               4156 non-null   float64
#  28  UUU               4156 non-null   float64
#  29  VEC               4156 non-null   int64
#  30  VVV               4156 non-null   float64
#  31  WSD               4156 non-null   float64
#  32  baseTm            4156 non-null   int64
#  33  newCon            4156 non-null   int64
# dtypes: float64(8), int64(19), object(7)
# memory usage: 1.1+ MB

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np

X_train, X_test, y_train, y_test = train_test_split(df_bus_100100073_weather[['fullSectDist','baseTm','RN1','T1H','VEC','WSD','newCon']], df_bus_100100073_weather['interval'],test_size=0.3, random_state=0)

# 선형 회귀를 이용하여 학습 및 예측 수행. 
lr = LinearRegression()
lr.fit(X_train, y_train)
lr_preds = lr.predict(X_test)

lr_mse = mean_squared_error(y_test, lr_preds)
lr_rmse = np.sqrt(lr_mse)

print('MSE : {: .3f}, RMSE : {: .3f}' .format(lr_mse, lr_rmse))
print('Variance score : {0: .3f}' .format(r2_score(y_test, lr_preds)))
# Out:
# MSE :  1.154, RMSE :  1.074
# Variance score :  0.694

# %%
#R2 score는 실제 분산값과 비교한 결과로 1에 가까울 수록 정확도가 높은 것(p304) 예측 v/실제 v

# %%
# 각 feature가 회귀 결과에 미치는 영향이 어느 정도인지 시각화 (linear)
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(30,20))
plt.subplot(5,2,1)
sns.regplot(x='fullSectDist',y='interval', data= df_bus_100100073_weather)
plt.subplot(5,2,2)
sns.regplot(x='baseTm',y='interval', data= df_bus_100100073_weather)
plt.subplot(5,2,3)
sns.regplot(x='RN1',y='interval', data= df_bus_100100073_weather)
plt.subplot(5,2,4)
sns.regplot(x='T1H',y='interval', data= df_bus_100100073_weather)
plt.subplot(5,2,5)
sns.regplot(x='VEC',y='interval', data= df_bus_100100073_weather)
plt.subplot(5,2,6)
sns.regplot(x='WSD',y='interval', data= df_bus_100100073_weather)
plt.subplot(5,2,7)
sns.regplot(x='newCon',y='interval', data= df_bus_100100073_weather)
plt.subplot(5,2,8)
sns.regplot(x='gpsX',y='interval', data= df_bus_100100073_weather)
plt.subplot(5,2,9)
sns.regplot(x='gpsY',y='interval', data= df_bus_100100073_weather)
plt.show()

# %%
# 1) fullsection 2) gpsX,gpsY

# %% [markdown]
# **상단에서 가장 연관성이 높아 보였던 fullsectdist, RN1, WSD 만 넣고 linear regression을 돌린 결과**

# %%
X_train, X_test, y_train, y_test = train_test_split(df_bus_100100073_weather[['fullSectDist','WSD','RN1']], df_bus_100100073_weather['interval'],test_size=0.3, random_state=0)


# 선형 회귀를 이용하여 학습 및 예측 수행. 
lr = LinearRegression()
lr.fit(X_train, y_train)
lr_preds = lr.predict(X_test)

lr_mse = mean_squared_error(y_test, lr_preds)
lr_rmse = np.sqrt(lr_mse)

print('MSE : {: .3f}, RMSE : {: .3f}' .format(lr_mse, lr_rmse))
print('Variance score : {0: .3f}' .format(r2_score(y_test, lr_preds)))
# Out:
# MSE :  1.149, RMSE :  1.072
# Variance score :  0.695

# %% [markdown]
# **상단에서 가장 연관성이 높아 보였던 gpsX, gpsY, RN1, WSD 만 넣고 linear regression을 돌린 결과**

# %%
X_train, X_test, y_train, y_test = train_test_split(df_bus_100100073_weather[['gpsX','gpsY','WSD','RN1']], df_bus_100100073_weather['interval'],test_size=0.3, random_state=0)


# 선형 회귀를 이용하여 학습 및 예측 수행. 
lr = LinearRegression()
lr.fit(X_train, y_train)
lr_preds = lr.predict(X_test)

lr_mse = mean_squared_error(y_test, lr_preds)
lr_rmse = np.sqrt(lr_mse)

print('MSE : {: .3f}, RMSE : {: .3f}' .format(lr_mse, lr_rmse))
print('Variance score : {0: .3f}' .format(r2_score(y_test, lr_preds)))
# Out:
# MSE :  1.134, RMSE :  1.065
# Variance score :  0.699

# %% [markdown]
# **타겟 정규화**

# %%
plt.figure(figsize=(9,6))
df_bus_100100073_weather['interval'].hist()
plt.show()

# %%
log_interval = np.log1p(df_bus_100100073_weather['interval'])

# %%
plt.figure(figsize=(9,6))
log_interval.hist()
plt.show()

# %% [markdown]
# **fullsecdis, RN1, WSD 만 넣고 data정규화 이후 linear regression을 돌린 결과**

# %%
X_train, X_test, y_train, y_test = train_test_split(df_bus_100100073_weather[['fullSectDist','WSD','RN1']], log_interval,test_size=0.3, random_state=0)

# 정규화 이후 선형 회귀를 이용하여 학습 및 예측 수행. 
lr = LinearRegression()
lr.fit(X_train, y_train)
lr_preds = lr.predict(X_test)

lr_mse = mean_squared_error(y_test, lr_preds)
lr_rmse = np.sqrt(lr_mse)

print('MSE : {: .3f}, RMSE : {: .3f}' .format(lr_mse, lr_rmse))
print('Variance score : {0: .3f}' .format(r2_score(y_test, lr_preds)))
# Out:
# MSE :  0.052, RMSE :  0.229
# Variance score :  0.565

# %% [markdown]
# **gpsX, gpsY, RN1, WSD 만 넣고 data정규화 이후 linear regression을 돌린 결과**

# %%
X_train, X_test, y_train, y_test = train_test_split(df_bus_100100073_weather[['gpsX','gpsY','WSD','RN1']], log_interval,test_size=0.3, random_state=0)

# 정규화 이후 선형 회귀를 이용하여 학습 및 예측 수행. 
lr = LinearRegression()
lr.fit(X_train, y_train)
lr_preds = lr.predict(X_test)

lr_mse = mean_squared_error(y_test, lr_preds)
lr_rmse = np.sqrt(lr_mse)

print('MSE : {: .3f}, RMSE : {: .3f}' .format(lr_mse, lr_rmse))
print('Variance score : {0: .3f}' .format(r2_score(y_test, lr_preds)))
# Out:
# MSE :  0.051, RMSE :  0.226
# Variance score :  0.577

# %% [markdown]
# 결론: fullSecDis 보다 gpsX, gpsY를 feature로 사용하였을 때, MSE가 더 낮고, R2 score가 더 높게 나왔다. (예측정확도가 더 높다)
#       다만 데이터 정규화 작업 후에는 MSE가 낮아졌지만(target scale이 작아졌으므로), R2 score도 더 낮게 나와서 model의 예측 정확도가 더 떨어진다는 결론이 나온다.

# %% [markdown]
# **Random Forest**

# %%
X_train, X_test, y_train, y_test = train_test_split(df_bus_100100073_weather[['fullSectDist','sectionId','baseTm','RN1','T1H','VEC','WSD','newCon','gpsX','gpsY']], df_bus_100100073_weather['interval'],test_size=0.3, random_state=0)

from sklearn.ensemble import RandomForestRegressor
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

rf_clf = RandomForestRegressor(random_state = 0)
rf_clf.fit(X_train, y_train)
rf_pred = rf_clf.predict(X_test)

rf_mse = mean_squared_error(y_test, rf_pred)
rf_rmse = np.sqrt(rf_mse)

print('MSE : {: .3f}, RMSE : {: .3f}' .format(rf_mse, rf_rmse))
# Out:
# MSE :  0.873, RMSE :  0.934

# %%
from sklearn.model_selection import GridSearchCV

params = {'max_depth': [8, 10, 12],
 'min_samples_leaf': [1, 2, 4, 8],
 'min_samples_split': [2, 5, 10],
 'n_estimators': [50,100]}

rf_clf = RandomForestRegressor(random_state = 0, n_jobs = -1)
grid_cv = GridSearchCV(rf_clf, param_grid = params, scoring = mean_squared_error,cv = 2, n_jobs=-1)
grid_cv.fit(X_train, y_train)

print('최적 하이퍼 파라미터 : {0}' .format(grid_cv.best_params_))
# Out:
# 최적 하이퍼 파라미터 : {'max_depth': 8, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 50}

# %%
# 최적의 하이퍼 파라미터를 사용하여 ramdom forest regression
rf_clf1 = RandomForestRegressor(max_depth=8, min_samples_leaf=1, min_samples_split=2, n_estimators=50)

rf_clf1.fit(X_train,y_train)
rf1_pred = rf_clf1.predict(X_test)

rf1_mse = mean_squared_error(y_test, rf1_pred)
rf1_rmse = np.sqrt(rf1_mse)

print('MSE : {: .3f}, RMSE : {: .3f}' .format(rf1_mse, rf1_rmse))
# Out:
# MSE :  0.866, RMSE :  0.930

# %% [markdown]
# **가장 MSE가 낮았던 마지막 모델의 각 feature별 중요도를 시각화**

# %%
rf_clf1 = RandomForestRegressor(max_depth=8, min_samples_leaf=1, min_samples_split=2, n_estimators=50)
rf_clf1.fit(X_train,y_train)

feature_series = pd.Series(data=rf_clf1.feature_importances_, index = X_train.columns)
feature_series = feature_series.sort_values(ascending=True)
plt.figure(figsize=(13,9))
bar = sns.barplot(x= feature_series, y = feature_series.index)
plt.show(bar)

# %% [markdown]
# 최적의 하이퍼 파라미터를 사용하여 정규화된 데이터에 'sectionId'를 빼고 모델링한 결과 (sectionId와 현재위치는 비슷한 정보를 가지고 있으므로)

# %%
X_train, X_test, y_train, y_test = train_test_split(df_bus_100100073_weather[['baseTm','fullSectDist','RN1','T1H','VEC','WSD','newCon','gpsX','gpsY']], df_bus_100100073_weather['interval'],test_size=0.3, random_state=0)

# 최적의 하이퍼 파라미터를 사용하여 ramdom forest regression
rf_clf1 = RandomForestRegressor(max_depth=8, min_samples_leaf=1, min_samples_split=2, n_estimators=50)

rf_clf1.fit(X_train,y_train)
rf1_pred = rf_clf1.predict(X_test)

rf1_mse = mean_squared_error(y_test, rf1_pred)
rf1_rmse = np.sqrt(rf1_mse)

print('MSE : {: .3f}, RMSE : {: .3f}' .format(rf1_mse, rf1_rmse))
# Out:
# MSE :  0.861, RMSE :  0.928

# %% [markdown]
# 결론: 상단의 모델이 가장 오차가 낮았다.   MSE :  0.861, RMSE :  0.928
#       날씨는 버스 소요시간에 큰 영향을 주지 않는다. 특히 가장 영향을 줄 것이라고 예상한 한시간 이내의 강수량, RN1이 가장 중요도가 낮았다
#
#
#       (limitation: 1) 버스 운행 데이터는 주중 오전 9~ 오후 6:30, 2) 버스의 위치는 api에 10초마다/정류장에 출도착할 때마다 갱신되는데, 수집의 한계로 1분 간격으로만 수집, 3) 하나의 버스 루트에 중에서도 특정 정류장만 확인한 결과)
